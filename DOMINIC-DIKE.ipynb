# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv("Table1.csv")
df2 = pd.read_csv("Table2.csv")
df3 = pd.read_csv("Table3.csv")
df4 = pd.read_csv("Table4.csv")
df5 = pd.read_csv("Table5.csv")
df6 = pd.read_csv("Table6.csv")

# %%
df1.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3           Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN                  NaN        NaN
# 1        NaN        NaN        NaN        NaN                  NaN        NaN
# 2        NaN        NaN        NaN        NaN                  NaN        NaN
# 3        NaN        NaN        NaN        NaN       United Nations        NaN
# 4        NaN        NaN        NaN        NaN  Population Division        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 3        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 4        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
# ...

# %%
df1 = pd.read_csv('Table1.csv', header=14)
df1.head()
# Out:
#    Sort\norder Major area, region, country or area of destination Notes  \
# 0          NaN                                                NaN   NaN
# 1          1.0                                              WORLD   NaN
# 2          2.0                                  Developed regions   (b)
# 3          3.0                                 Developing regions   (c)
# 4          4.0                          Least developed countries   (d)
#
#    Country code Type of data (a)  \
# 0           NaN              NaN
# 1         900.0              NaN
# 2         901.0              NaN
# 3         902.0              NaN
# 4         941.0              NaN
#
#   International migrant stock at mid-year (both sexes)    Unnamed: 6  \
# 0                                               1990            1995
# 1                                        152 563 212     160 801 752
# 2                                         82 378 628      92 306 854
# ...

# %%
to_drop = ['Sort\norder', 'Notes', 'Type of data (a)']
df1.drop(to_drop, inplace=True, axis=1)

# %%
df1.head()
# Out:
#   Major area, region, country or area of destination  Country code  \
# 0                                                NaN           NaN
# 1                                              WORLD         900.0
# 2                                  Developed regions         901.0
# 3                                 Developing regions         902.0
# 4                          Least developed countries         941.0
#
#   International migrant stock at mid-year (both sexes)    Unnamed: 6  \
# 0                                               1990            1995
# 1                                        152 563 212     160 801 752
# 2                                         82 378 628      92 306 854
# 3                                         70 184 584      68 494 898
# 4                                         11 075 966      11 711 703
#
#      Unnamed: 7    Unnamed: 8    Unnamed: 9   Unnamed: 10  \
# 0          2000          2005          2010          2015
# ...

# %%
df1.columns = df1.iloc[0]

# %%
df1.head()
# Out:
# 0                        NaN    NaN          1990          1995          2000  \
# 0                        NaN    NaN          1990          1995          2000
# 1                      WORLD  900.0   152 563 212   160 801 752   172 703 309
# 2          Developed regions  901.0    82 378 628    92 306 854   103 375 363
# 3         Developing regions  902.0    70 184 584    68 494 898    69 327 946
# 4  Least developed countries  941.0    11 075 966    11 711 703    10 077 824
#
# 0          2005          2010          2015         1990         1995  \
# 0          2005          2010          2015         1990         1995
# 1   191 269 100   221 714 243   243 700 236   77 747 510   81 737 477
# 2   117 181 109   132 560 325   140 481 955   40 263 397   45 092 799
# 3    74 087 991    89 153 918   103 218 281   37 484 113   36 644 678
# 4     9 809 634    10 018 128    11 951 316    5 843 107    6 142 712
#
# 0         2000         2005          2010          2015         1990  \
# ...

# %%
df1.drop(0)
# Out:
# 0                                                  NaN    NaN          1990  \
# 1                                                WORLD  900.0   152 563 212
# 2                                    Developed regions  901.0    82 378 628
# 3                                   Developing regions  902.0    70 184 584
# 4                            Least developed countries  941.0    11 075 966
# 5    Less developed regions excluding least develop...  934.0    59 105 261
# ..                                                 ...    ...           ...
# 261                                              Samoa  882.0         3 357
# 262                                            Tokelau  772.0           270
# 263                                              Tonga  776.0         2 911
# 264                                             Tuvalu  798.0           318
# 265                          Wallis and Futuna Islands  876.0         1 402
#
# ...

# %%
df1.rename(columns={'NaN':'Sort ID', 'NaN':'Area Code'}, inplace=True)

# %%
df1.head()
# Out:
# 0                       type    NaN          1990          1995          2000  \
# 0                        NaN    NaN          1990          1995          2000
# 1                      WORLD  900.0   152 563 212   160 801 752   172 703 309
# 2          Developed regions  901.0    82 378 628    92 306 854   103 375 363
# 3         Developing regions  902.0    70 184 584    68 494 898    69 327 946
# 4  Least developed countries  941.0    11 075 966    11 711 703    10 077 824
#
# 0          2005          2010          2015         1990         1995  \
# 0          2005          2010          2015         1990         1995
# 1   191 269 100   221 714 243   243 700 236   77 747 510   81 737 477
# 2   117 181 109   132 560 325   140 481 955   40 263 397   45 092 799
# 3    74 087 991    89 153 918   103 218 281   37 484 113   36 644 678
# 4     9 809 634    10 018 128    11 951 316    5 843 107    6 142 712
#
# 0         2000         2005          2010          2015         1990  \
# ...
